# %% [markdown]
# ## 2026-09-17 함수 및 모듈, 패키지

# %%
def say():
    print("면적을 계산합니다.")
    return True

# %%
c = say()
print(type(c), c)
# Out:
# 면적을 계산합니다.
# <class 'bool'> True

# %%
def calc_area(shape, w, h=None, scale=1.0):
    area = None
    msg = None

    if shape == 1:  # 사각형
        area = w * h
        msg = '사각형'

    elif shape == 2:  # 삼각형
        area = w * h / 2
        msg = '삼각형'

    elif shape == 3:  # 원
        area = 3.141592 * (w/2)**2
        msg = '원'

    else:  # 지원하지 않음
        print("지원하지 않습니다.")

    area = area * scale if 1 <= shape <= 3 else area

    return area, msg

# %%
print('사각형의 면적:', calc_area(shape=1, w=10, h=20, scale=2.0))
print('사각형의 면적:', calc_area(w=10, h=20, shape=1, scale=2.0))
print('사각형의 면적:', calc_area(1, 10, 20))
# Out:
# 사각형의 면적: (400.0, '사각형')
# 사각형의 면적: (400.0, '사각형')
# 사각형의 면적: (200.0, '사각형')

# %%
a, m = calc_area(2, 10, 20)
print(a, m)

b = calc_area(3, 10)
print(b)
print(b[0], b[1])

c, _ = calc_area(4, 5, 6,)
print(c)
print(_)

d, _ = calc_area(3, 10)
print(d, type(_), _)
# Out:
# 100.0 삼각형
# (78.5398, '원')
# 78.5398 원
# 지원하지 않습니다.
# None
# None
# 78.5398 <class 'str'> 원
